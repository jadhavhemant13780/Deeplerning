# %% [markdown]
# <a href="https://colab.research.google.com/github/jadhavhemant13780/Deeplerning/blob/main/Binary_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Binary classification

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
url="https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/booking_train.csv"
df= pd.read_csv(url)
df.head()
# Out:
#    id  no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0   0             2               0                     0                  2
# 1   1             2               0                     1                  2
# 2   2             2               0                     0                  1
# 3   3             1               0                     0                  2
# 4   4             2               0                     1                  0
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  1                           0                   0
# 1                  0                           0                   0
# 2                  0                           0                   0
# 3                  1                           0                   0
# 4                  0                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %% [markdown]
# ## Step 2 - Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42100 entries, 0 to 42099
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    42100 non-null  int64
#  1   no_of_adults                          42100 non-null  int64
#  2   no_of_children                        42100 non-null  int64
#  3   no_of_weekend_nights                  42100 non-null  int64
#  4   no_of_week_nights                     42100 non-null  int64
#  5   type_of_meal_plan                     42100 non-null  int64
#  6   required_car_parking_space            42100 non-null  int64
#  7   room_type_reserved                    42100 non-null  int64
#  8   lead_time                             42100 non-null  int64
#  9   arrival_year                          42100 non-null  int64
#  10  arrival_month                         42100 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                      0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Step 3 - Seperate X and Y(booking_status)

# %% [markdown]
# ## id is just a serial number column

# %%
X = df.drop(columns=["id", "booking_status"])
Y = df[["booking_status"]]

# %%
X.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     0                  2
# 1             2               0                     1                  2
# 2             2               0                     0                  1
# 3             1               0                     0                  2
# 4             2               0                     1                  0
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  1                           0                   0
# 1                  0                           0                   0
# 2                  0                           0                   0
# 3                  1                           0                   0
# 4                  0                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %%
Y.head()
# Out:
#    booking_status
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1

# %%
Y.value_counts()
# Out:
# booking_status
# 0                 25596
# 1                 16504
# Name: count, dtype: int64

# %%
Y.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_status'>

# %% [markdown]
# ## Step 4 - Apply preprocessing on X

# %%
X.dtypes
# Out:
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                         int64
# required_car_parking_space                int64
# room_type_reserved                        int64
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                       int64
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0      0.151040       -0.313454             -0.998814          -0.278849
# 1      0.151040       -0.313454              0.130259          -0.278849
# 2      0.151040       -0.313454             -0.998814          -0.979466
# 3     -1.753925       -0.313454             -0.998814          -0.278849
# 4      0.151040       -0.313454              0.130259          -1.680084
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0           1.294624                   -0.160945           -0.515173
# 1          -0.407020                   -0.160945           -0.515173
# 2          -0.407020                   -0.160945           -0.515173
# 3           1.294624                   -0.160945           -0.515173
# 4          -0.407020                   -0.160945           -0.515173
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %% [markdown]
# ## Step 5 - Train Test Split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 15559      0.151040       -0.313454             -0.998814           0.421768
# 32783      0.151040       -0.313454              0.130259           1.122386
# 11797      2.056005       -0.313454             -0.998814           0.421768
# 39750      0.151040       -0.313454             -0.998814          -0.979466
# 28711      0.151040       -0.313454              1.259332           0.421768
#
#        type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 15559          -0.407020                   -0.160945            0.685890
# 32783          -0.407020                   -0.160945            0.685890
# 11797          -0.407020                   -0.160945            0.685890
# 39750           2.996268                   -0.160945           -0.515173
# 28711          -0.407020                   -0.160945            0.685890
#
#        lead_time  arrival_year  arrival_month  arrival_date  \
# ...

# %%
ytrain.head()
# Out:
#        booking_status
# 15559               0
# 32783               0
# 11797               1
# 39750               1
# 28711               1

# %%
xtest.head()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 8768        0.15104       -0.313454             -0.998814           0.421768
# 38340       0.15104       -0.313454             -0.998814          -0.278849
# 7104        0.15104       -0.313454              1.259332          -0.979466
# 36898       0.15104        1.908162              1.259332           1.122386
# 9747        0.15104       -0.313454              1.259332           0.421768
#
#        type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 8768            -0.40702                   -0.160945           -0.515173
# 38340           -0.40702                   -0.160945           -0.515173
# 7104            -0.40702                   -0.160945            4.289080
# 36898           -0.40702                   -0.160945           -0.515173
# 9747            -0.40702                   -0.160945           -0.515173
#
#        lead_time  arrival_year  arrival_month  arrival_date  \
# ...

# %%
ytest.head()
# Out:
#        booking_status
# 8768                0
# 38340               1
# 7104                0
# 36898               0
# 9747                0

# %%
xtrain.shape
# Out:
# (33680, 17)

# %%
xtest.shape
# Out:
# (8420, 17)

# %%
xtrain.shape[1]
# Out:
# 17

# %% [markdown]
# ## Step 6 - Build the neural network

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout

# %%
# Intialize the model
model = Sequential()

# Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Dense Layer 1
model.add(Dense(units=32, activation="relu"))

# Dropout Layer 1
model.add(Dropout(rate=0.3))

# Dense Layer 2
model.add(Dense(units=16, activation="relu"))

# Dropout Layer 2
model.add(Dropout(rate=0.2))

# Output Layer
model.add(Dense(units=1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ...

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=60)
# Out:
# Epoch 1/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6850 - loss: 0.5791 - val_accuracy: 0.7715 - val_loss: 0.4842
# Epoch 2/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7692 - loss: 0.4911 - val_accuracy: 0.7761 - val_loss: 0.4775
# Epoch 3/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7721 - loss: 0.4831 - val_accuracy: 0.7789 - val_loss: 0.4733
# Epoch 4/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7747 - loss: 0.4760 - val_accuracy: 0.7813 - val_loss: 0.4715
# Epoch 5/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7828 - loss: 0.4741 - val_accuracy: 0.7833 - val_loss: 0.4698
# Epoch 6/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7886 - loss: 0.4628 - val_accuracy: 0.7849 - val_loss: 0.4670
# Epoch 7/60
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7790 - loss: 0.4761 - val_accuracy: 0.7856 - val_loss: 0.4673
# Epoch 8/60
# ...

# %% [markdown]
# ## Plot the learning curve

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
plt.plot(hist.history["loss"], label="Train Loss")
plt.plot(hist.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Binary Cross Entropy")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %% [markdown]
# ## Model evaluation

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 1053/1053 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8055 - loss: 0.4283
# [0.42933857440948486, 0.8054928779602051]

# %%
model.evaluate(xtest, ytest)
# Out:
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8038 - loss: 0.4347
# [0.43270349502563477, 0.801306426525116]

# %% [markdown]
# ## Detailed model evaluation

# %%
yprob_train = model.predict(xtrain)
yprob_train[0:5]
# Out:
# 1053/1053 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# array([[0.00548098],
#        [0.20488071],
#        [0.75759673],
#        [0.8079179 ],
#        [0.8243001 ]], dtype=float32)

# %% [markdown]
# ## If prob >= 0.5 classify as 1
# If prob < 0.5 classify as 0

# %%
ypred_train = [1 if prob >= 0.5 else 0 for prob in yprob_train]
ypred_train[0:5]
# Out:
# [0, 0, 1, 1, 1]

# %%
ytrain.head()
# Out:
#        booking_status
# 15559               0
# 32783               0
# 11797               1
# 39750               1
# 28711               1

# %%
yprob_test = model.predict(xtest)
yprob_test[0:5]
# Out:
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.04491168],
#        [0.8921107 ],
#        [0.32566592],
#        [0.02313792],
#        [0.21533029]], dtype=float32)

# %%
ypred_test = [1 if prob >= 0.5 else 0 for prob in yprob_test]
ypred_test[0:5]
# Out:
# [0, 1, 0, 0, 0]

# %%
ytest.head()
# Out:
#        booking_status
# 8768                0
# 38340               1
# 7104                0
# 36898               0
# 9747                0

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(ytest, ypred_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      5150
#            1       0.77      0.70      0.73      3270
#
#     accuracy                           0.80      8420
#    macro avg       0.79      0.78      0.79      8420
# weighted avg       0.80      0.80      0.80      8420

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(ytest, yprob_test)

# %% [markdown]
# ## Above model is good model and can be used for out of sample prediction

# %% [markdown]
# ## Step 8 - Out of sample prediction

# %%
url2 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/booking_test.csv"
xnew = pd.read_csv(url2)
xnew.head()
# Out:
#       id  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0  42100             3               0                     1
# 1  42101             2               0                     0
# 2  42102             2               2                     0
# 3  42103             2               0                     0
# 4  42104             1               0                     0
#
#    no_of_week_nights  type_of_meal_plan  required_car_parking_space  \
# 0                  4                  0                           0
# 1                  3                  0                           0
# 2                  1                  0                           0
# 3                  3                  0                           0
# 4                  2                  2                           0
#
#    room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0                   1        111          2018             12             5
# ...

# %%
xnew2 = xnew.drop(columns=["id"])
xnew2.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             3               0                     1                  4
# 1             2               0                     0                  3
# 2             2               2                     0                  1
# 3             2               0                     0                  3
# 4             1               0                     0                  2
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  0                           0                   1
# 1                  0                           0                   0
# 2                  0                           0                   3
# 3                  0                           0                   0
# 4                  2                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
xnew2_pre = num_pipe.transform(xnew2)
xnew2_pre.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0      2.056005       -0.313454              0.130259           1.122386
# 1      0.151040       -0.313454             -0.998814           0.421768
# 2      0.151040        4.129777             -0.998814          -0.979466
# 3      0.151040       -0.313454             -0.998814           0.421768
# 4     -1.753925       -0.313454             -0.998814          -0.278849
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0          -0.407020                   -0.160945            0.685890
# 1          -0.407020                   -0.160945           -0.515173
# 2          -0.407020                   -0.160945            3.088017
# 3          -0.407020                   -0.160945           -0.515173
# 4           2.996268                   -0.160945           -0.515173
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...

# %%
probs = model.predict(xnew2_pre)
probs[0:5]
# Out:
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.0832082 ],
#        [0.03279393],
#        [0.33278137],
#        [0.19198155],
#        [0.5994873 ]], dtype=float32)

# %%
preds = [1 if p >= 0.5 else 0 for p in probs]
preds[0:5]
# Out:
# [0, 0, 0, 0, 1]

# %%
res = xnew[["id"]]
res.head()
# Out:
#       id
# 0  42100
# 1  42101
# 2  42102
# 3  42103
# 4  42104

# %%
res["booking_pred"] = preds
res["booking_prob"] = probs
res = res.round(4)
res
# Out:
#           id  booking_pred  booking_prob
# 0      42100             0        0.0832
# 1      42101             0        0.0328
# 2      42102             0        0.3328
# 3      42103             0        0.1920
# 4      42104             1        0.5995
# ...      ...           ...           ...
# 28063  70163             1        0.9532
# 28064  70164             0        0.0542
# 28065  70165             0        0.1279
# 28066  70166             1        0.5082
# 28067  70167             1        0.7590
#
# [28068 rows x 3 columns]

# %%
res["booking_pred"].value_counts()
# Out:
# booking_pred
# 0    18140
# 1     9928
# Name: count, dtype: int64

# %%
res["booking_pred"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_pred'>

# %%
res.to_csv("BookingResults.csv", index=False)

# %% [markdown]
# ## Save the model

# %%
model.save("booking.keras")

# %% [markdown]
# ## Load this model

# %%
from keras.models import load_model

# %%
nn = load_model("/content/booking.keras")
nn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ...
